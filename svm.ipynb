# %%
# Setup

import numpy as np

# Ein Zufalls-Seed für Reproduzierbarkeit
np.random.seed(42)

from datetime import datetime
import pandas as pd
from scipy import stats
import sklearn as sklearn
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score, classification_report
from sklearn.impute import KNNImputer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

from IPython.display import display, clear_output

# %%
# Daten importieren
data = pd.read_csv('data/diabetes.csv')

# Nullen durch NaN ersetzen
data["Glucose"] = data["Glucose"].replace(0, np.nan)
data["BloodPressure"] = data["BloodPressure"].replace(0, np.nan)
data["SkinThickness"] = data["SkinThickness"].replace(0, np.nan)
data["Insulin"] = data["Insulin"].replace(0, np.nan)
data["BMI"] = data["BMI"].replace(0, np.nan)
data["DiabetesPedigreeFunction"] = data["DiabetesPedigreeFunction"].replace(0, np.nan)
data["Age"] = data["Age"].replace(0, np.nan)

# NaN Werte imputieren
imputer = KNNImputer(n_neighbors=3)

data_imputed = pd.DataFrame(imputer.fit_transform(data))
data_imputed.columns = data.columns

# %%
def svm_func(random_state):
    # Input-Daten
    X = data_imputed[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']].values
    # Der Wert, der vorhergesagt werden soll
    y = data_imputed['Outcome'].values

    # Train-Test-Split als 70/30
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=random_state)

    clf = make_pipeline(StandardScaler(), svm.SVC(C=300, kernel='poly', gamma='scale', degree=8, verbose=True))
    clf.fit(X_train, y_train)

    predictions = clf.predict(X_test)

    #report = classification_report(y_test, predictions)
    #matrix = confusion_matrix(y_test, predictions)
    f1 = f1_score(y_test, predictions, average='macro')
    
    return clf, f1

    #print(matrix)
    #print(report)

# %%
# 100 verschiedene Modelle trainieren und in einen DataFrame speichern
# Das kann ein paar Stunden dauern

results = {}

for i in np.arange(50):
    model, f1 = svm_func(i)
    results[i] = [model, f1]
    clear_output()
    df_results = pd.DataFrame.from_dict(results, orient='index', columns=['model', 'f1'])
    display(df_results)
# Out:
#                                                 model        f1
# 0   (StandardScaler(), SVC(C=300, degree=8, kernel...  0.905130
# 1   (StandardScaler(), SVC(C=300, degree=8, kernel...  0.912051
# 2   (StandardScaler(), SVC(C=300, degree=8, kernel...  0.889334
# 3   (StandardScaler(), SVC(C=300, degree=8, kernel...  0.916640
# 4   (StandardScaler(), SVC(C=300, degree=8, kernel...  0.901602
# 5   (StandardScaler(), SVC(C=300, degree=8, kernel...  0.931808
# 6   (StandardScaler(), SVC(C=300, degree=8, kernel...  0.905542
# 7   (StandardScaler(), SVC(C=300, degree=8, kernel...  0.905745
# 8   (StandardScaler(), SVC(C=300, degree=8, kernel...  0.934794
# 9   (StandardScaler(), SVC(C=300, degree=8, kernel...  0.914124
# 10  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.915322
# 11  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.899686
# 12  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.887695
# 13  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.905633
# 14  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.906188
# 15  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.909278
# 16  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.914728
# 17  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.913171
# 18  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.909477
# 19  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.901422
# 20  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.904477
# 21  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.917176
# 22  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.907052
# 23  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.909302
# 24  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.917524
# 25  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.896632
# 26  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.909878
# 27  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.907834
# 28  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.906144
# 29  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.923896
# 30  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.899869
# 31  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.906945
# 32  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.907798
# 33  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.922292
# 34  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.916213
# 35  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.918932
# 36  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.914698
# 37  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.934038
# 38  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.919466
# 39  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.900472
# 40  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.918773
# 41  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.938167
# 42  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.911722
# 43  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.910197
# 44  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.905238
# 45  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.905238
# 46  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.903617
# 47  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.897296
# 48  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.908669
# 49  (StandardScaler(), SVC(C=300, degree=8, kernel...  0.916415

# %%
# DataFrame nach bestem F1-Score sortieren
df_results_sorted = df_results.sort_values(by=['f1'], ascending=False)

# %%
df_results.describe()
# Out:
#               f1
# count  50.000000
# mean    0.910707
# std     0.010432
# min     0.887695
# 25%     0.905238
# 50%     0.909290
# 75%     0.916365
# max     0.938167
