# %%
# Setup

import numpy as np

# Ein Zufalls-Seed für Reproduzierbarkeit
np.random.seed(42)

from datetime import datetime
import pandas as pd
from scipy import stats
import sklearn as sklearn
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score, classification_report, matthews_corrcoef
from sklearn.impute import KNNImputer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

from IPython.display import display, clear_output

# %%
# Daten importieren
data = pd.read_csv('data/diabetes.csv')

# Nullen durch NaN ersetzen
data["Glucose"] = data["Glucose"].replace(0, np.nan)
data["BloodPressure"] = data["BloodPressure"].replace(0, np.nan)
data["SkinThickness"] = data["SkinThickness"].replace(0, np.nan)
data["Insulin"] = data["Insulin"].replace(0, np.nan)
data["BMI"] = data["BMI"].replace(0, np.nan)
data["DiabetesPedigreeFunction"] = data["DiabetesPedigreeFunction"].replace(0, np.nan)
data["Age"] = data["Age"].replace(0, np.nan)

# NaN Werte imputieren
imputer = KNNImputer(n_neighbors=3)

data_imputed = pd.DataFrame(imputer.fit_transform(data))
data_imputed.columns = data.columns

# %%
def svm_func(random_state):
    # Input-Daten
    X = data_imputed[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']].values
    # Der Wert, der vorhergesagt werden soll
    y = data_imputed['Outcome'].values

    # Train-Test-Split als 70/30
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=random_state)

    clf = make_pipeline(StandardScaler(), svm.SVC(C=300, kernel='poly', gamma='scale', degree=6, verbose=True))
    clf.fit(X_train, y_train)

    predictions = clf.predict(X_test)

    #report = classification_report(y_test, predictions)
    #matrix = confusion_matrix(y_test, predictions)
    f1 = f1_score(y_test, predictions, average='macro')
    mcc = matthews_corrcoef(y_test, predictions)
    
    return clf, f1, mcc

    #print(matrix)
    #print(report)

# %%
# 100 verschiedene Modelle trainieren und in einen DataFrame speichern
# Das kann ein paar Stunden dauern

results = {}

for i in np.arange(50):
    model, f1, mcc = svm_func(i)
    results[i] = [model, f1, mcc]
    clear_output()
    df_results = pd.DataFrame.from_dict(results, orient='index', columns=['model', 'f1', 'mcc'])
    display(df_results)
# Out:
#                                                 model        f1       mcc
# 0   (StandardScaler(), SVC(C=300, degree=6, kernel...  0.927233  0.858153
# 1   (StandardScaler(), SVC(C=300, degree=6, kernel...  0.931811  0.870929
# 2   (StandardScaler(), SVC(C=300, degree=6, kernel...  0.923770  0.851021
# 3   (StandardScaler(), SVC(C=300, degree=6, kernel...  0.924114  0.858049
# 4   (StandardScaler(), SVC(C=300, degree=6, kernel...  0.935218  0.876336
# 5   (StandardScaler(), SVC(C=300, degree=6, kernel...  0.943668  0.890251
# 6   (StandardScaler(), SVC(C=300, degree=6, kernel...  0.929710  0.861975
# 7   (StandardScaler(), SVC(C=300, degree=6, kernel...  0.927830  0.862541
# 8   (StandardScaler(), SVC(C=300, degree=6, kernel...  0.952422  0.907753
# 9   (StandardScaler(), SVC(C=300, degree=6, kernel...  0.928679  0.864718
# 10  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.938843  0.880433
# 11  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.925205  0.856632
# 12  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.921338  0.844948
# 13  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.928569  0.862243
# 14  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.922337  0.849331
# 15  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.925756  0.859491
# 16  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.936663  0.876941
# 17  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.931264  0.864629
# 18  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.927683  0.858569
# 19  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.924114  0.858049
# 20  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.915388  0.834452
# 21  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.943492  0.889211
# 22  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.930606  0.866355
# 23  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.932188  0.867443
# 24  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.929346  0.860054
# 25  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.914001  0.836135
# 26  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.917706  0.842674
# 27  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.932598  0.872963
# 28  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.922435  0.855930
# 29  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.941192  0.886676
# 30  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.928261  0.863963
# 31  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.921244  0.846078
# 32  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.949049  0.902452
# 33  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.936157  0.875538
# 34  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.927975  0.861611
# 35  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.945595  0.892802
# 36  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.929986  0.864398
# 37  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.948556  0.899105
# 38  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.935896  0.875967
# 39  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.919156  0.844652
# 40  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.947019  0.897746
# 41  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.951275  0.906078
# 42  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.926768  0.855633
# 43  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.935218  0.875758
# 44  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.928261  0.862142
# 45  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.925793  0.856086
# 46  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.929585  0.863911
# 47  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.916415  0.839149
# 48  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.936558  0.878180
# 49  (StandardScaler(), SVC(C=300, degree=6, kernel...  0.939243  0.880287

# %%
# DataFrame nach bestem F1-Score sortieren
df_results_sorted = df_results.sort_values(by=['f1', 'mcc'], ascending=False)

# %%
df_results.describe()
# Out:
#               f1        mcc
# count  50.000000  50.000000
# mean    0.931264   0.867328
# std     0.009481   0.017997
# min     0.914001   0.834452
# 25%     0.925343   0.856986
# 50%     0.929465   0.863937
# 75%     0.936458   0.876790
# max     0.952422   0.907753
